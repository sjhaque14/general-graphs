# %%
import numpy as np
import scipy.linalg
import scipy.signal
import scipy.optimize
import networkx as nx
import matplotlib.pyplot as plt
import math
from tqdm import tqdm

from general_graph_utils import *

# %%
plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(14,12))
# %config InlineBackend.figure_format = 'retina'

# %%
def unicycle_graph(n):
    """
    Generates a reversible unicyclic linear framework graph of size n.
    
    Parameters
    ----------
    n : integer
        the size (or number of vertices) of the graph
    
    Returns
    -------
    G : NetworkX DiGraph object
        directed graph
    
    G_ud : NetworkX Graph object
        undirected graph
    """
    
    G = nx.DiGraph()
    G_ud = nx.Graph()
    
    # determine the number of nodes in G
    G_size = n
    
    # add nodes to G and G_ud
    nodes = np.arange(1,G_size+1,step=1)
    G.add_nodes_from(nodes)
    G_ud.add_nodes_from(nodes)
    
    for i in range(2,G_size+1):
        u = i-1
        v = i
        G.add_edge(u,v)
        G.add_edge(v,u)
        G_ud.add_edge(u,v)
        
    G.add_edge(G_size,1)
    G.add_edge(1,G_size)
    G_ud.add_edge(1,G_size)
    
    return G, G_ud

# %%
# Function to compute the correlation function C(t)
def correlation_function_general(t, W, n):
    exp_Wt = scipy.linalg.expm(W * t) # Compute the matrix exponential e^(Wt)
    #p = np.zeros((1,n))
    #p[0] = 1
    #return (exp_Wt[0]*p)[0] # e^(Wt)[11] Prob of being in 1 at time t given was in 1 at time 0
    return exp_Wt[0][0]

# %%
N = 40
G, G_ud = unicycle_graph(N)

# %%
node_list = get_nodes(G)
num_nodes = len(node_list)
edge_list = get_edges(G)

cycle_list = get_cycles(G_ud)
num_cycles = len(cycle_list)

# %%
node_labels = {}

for node in node_list:
    node_labels[node] = str(node)

nx.draw(G, pos=nx.circular_layout(G), labels=node_labels, with_labels=True,node_size=1000, node_color = 'lightgray', font_size=20, font_color='black', font_family='sans-serif')

# %%
# parameter values from Barato Seifert 2017
k_m = 1.0
A = 200
k_p = k_m*np.exp(A/N)

# %%
edge_labels_forward = np.array([])
edge_labels_backward = np.array([])

for i in range(num_nodes-1):
    u = cycle_list[0][i]
    v = cycle_list[0][i+1]
    
    G[u][v]['weight'] = k_p
    edge_labels_forward = np.append(edge_labels_forward, k_p)
    
    G[v][u]['weight'] = k_m
    edge_labels_backward = np.append(edge_labels_backward, k_m)

G[cycle_list[0][-1]][cycle_list[0][0]]['weight'] = k_p
edge_labels_forward = np.append(edge_labels_forward, k_p)
G[cycle_list[0][0]][cycle_list[0][-1]]['weight'] = k_m
edge_labels_backward = np.append(edge_labels_backward, k_m)

# %%
label_dict = {e: G[e[0]][e[1]]['weight'] for e in G.edges}

# %%
label_list = np.fromiter(label_dict.values(), dtype=float)

# %%
W = Laplacian_all(edge_list,label_list,node_list)

# %%
affinity = np.log(np.prod(edge_labels_forward)/np.prod(edge_labels_backward))
affinity
# Out:
# 200.0

# %%
# eigenvalues of W
W = Laplacian_all(edge_list,label_list,node_list)
eigvals, eigvecs = scipy.linalg.eig(W)

x_i = np.abs(np.sort(eigvals)[-2].imag)
x_r = np.abs(np.sort(eigvals)[-2].real)

print(x_i, x_r)

# decay time
tau = 1/x_r
print("decay time: " + str(tau))

# oscillation period
omega = (2*math.pi)/x_i
print("period: " + str(omega))

# number of coherent oscillations
R = x_i/x_r
print("number coherent oscillations: " + str(R/2*math.pi))

# Time points for the plot
times = np.linspace(0.1, 5, 500)  # time from 0 to 1.5 with 500 pts
# Compute C(t) for each time point
correlation_values = [correlation_function_general(t, W, n=40) for t in tqdm(times)]
# Out:
# 23.06049868410202 1.8395248228988317
# decay time: 0.5436186495293611
# period: 0.27246528330765174
# number coherent oscillations: 19.691686774828682
#   0%|                                                   | 0/500 [00:00<?, ?it/s]
#   0%|                                           | 1/500 [00:00<01:06,  7.52it/s]
#   1%|▎                                          | 3/500 [00:00<00:50,  9.82it/s]
#   1%|▍                                          | 5/500 [00:00<00:48, 10.28it/s]
#   1%|▌                                          | 7/500 [00:00<00:46, 10.55it/s]
#   2%|▊                                          | 9/500 [00:00<00:46, 10.58it/s]
#   2%|▉                                         | 11/500 [00:01<00:47, 10.27it/s]
#   3%|█                                         | 13/500 [00:01<00:52,  9.25it/s]
#   3%|█▏                                        | 14/500 [00:01<00:55,  8.76it/s]
#   3%|█▎                                        | 15/500 [00:01<00:57,  8.43it/s]
#   3%|█▎                                        | 16/500 [00:01<00:58,  8.32it/s]
#   3%|█▍                                        | 17/500 [00:01<00:58,  8.22it/s]
#   4%|█▌                                        | 18/500 [00:01<00:58,  8.18it/s]
#   4%|█▌                                        | 19/500 [00:02<00:59,  8.12it/s]
#   4%|█▋                                        | 20/500 [00:02<01:00,  7.98it/s]
#   4%|█▊                                        | 21/500 [00:02<01:01,  7.79it/s]
#   4%|█▊                                        | 22/500 [00:02<01:01,  7.80it/s]
#   5%|█▉                                        | 23/500 [00:02<01:00,  7.88it/s]
#   5%|██                                        | 24/500 [00:02<01:00,  7.91it/s]
#   5%|██                                        | 25/500 [00:02<01:00,  7.89it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ch/f1rl6h5x4fx2wbg2_f5bj5dw0000gn/T/ipykernel_16635/2121138409.py in <module>
#      23 times = np.linspace(0.1, 5, 500)  # time from 0 to 1.5 with 500 pts
#      24 # Compute C(t) for each time point
# ---> 25 correlation_values = [correlation_function_general(t, W, n=40) for t in tqdm(times)]
#
# /var/folders/ch/f1rl6h5x4fx2wbg2_f5bj5dw0000gn/T/ipykernel_16635/2121138409.py in <listcomp>(.0)
#      23 times = np.linspace(0.1, 5, 500)  # time from 0 to 1.5 with 500 pts
#      24 # Compute C(t) for each time point
# ---> 25 correlation_values = [correlation_function_general(t, W, n=40) for t in tqdm(times)]
#
# /var/folders/ch/f1rl6h5x4fx2wbg2_f5bj5dw0000gn/T/ipykernel_16635/1682104645.py in correlation_function_general(t, W, n)
#       1 # Function to compute the correlation function C(t)
#       2 def correlation_function_general(t, W, n):
# ----> 3     exp_Wt = scipy.linalg.expm(W * t) # Compute the matrix exponential e^(Wt)
#       4     #p = np.zeros((1,n))
#       5     #p[0] = 1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/matfuncs.py in expm(A)
#     253     # Input checking and conversion is provided by sparse.linalg.expm().
#     254     import scipy.sparse.linalg
# --> 255     return scipy.sparse.linalg.expm(A)
#     256
#     257
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in expm(A)
#     589             [  0.        ,   0.        ,  20.08553692]])
#     590     """
# --> 591     return _expm(A, use_exact_onenorm='auto')
#     592
#     593
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in _expm(A, use_exact_onenorm)
#     650
#     651     # Try Pade orders 7 and 9.
# --> 652     eta_3 = max(h.d6_tight, h.d8_loose)
#     653     if eta_3 < 9.504178996162932e-001 and _ell(h.A, 7) == 0:
#     654         U, V = h.pade7()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in d8_loose(self)
#     465     def d8_loose(self):
#     466         if self.use_exact_onenorm:
# --> 467             return self.d8_tight
#     468         if self._d8_exact is not None:
#     469             return self._d8_exact
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in d8_tight(self)
#     429     def d8_tight(self):
#     430         if self._d8_exact is None:
# --> 431             self._d8_exact = _onenorm(self.A8)**(1/8.)
#     432         return self._d8_exact
#     433
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in A8(self)
#     403     def A8(self):
#     404         if self._A8 is None:
# --> 405             self._A8 = _smart_matrix_product(
#     406                     self.A6, self.A2, structure=self.structure)
#     407         return self._A8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in _smart_matrix_product(A, B, alpha, structure)
#     164     else:
#     165         if alpha is None:
# --> 166             out = A.dot(B)
#     167         else:
#     168             out = alpha * A.dot(B)
#
# KeyboardInterrupt:
