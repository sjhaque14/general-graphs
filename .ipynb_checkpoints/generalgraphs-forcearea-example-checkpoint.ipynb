# %%
import numpy as np
import scipy.linalg
import networkx as nx
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
from general_graph_utils import *

# %% [markdown]
# ## Create directed and undirected versions of a graph (both unweighted)

# %%
# G_ex1 = nx.DiGraph()
# G_ex1.add_nodes_from([1,2,3,4,5])
# G_ex1.add_edges_from([(1,2),(2,1),(2,4),(4,2),(2,3),(3,2),(3,4),(4,3),(1,4),(4,1),(5,2),(5,1),(2,5),(1,5)])

# %%
# G_ex2 = nx.DiGraph()
# G_ex2.add_nodes_from([1,2,3,4,5])
# G_ex2.add_edges_from([(1,2), (2,1), (2,4), (4,2), (2,3), (3,2), (3,5), (5,3), (1,4), (4,1),(5,2),(2,5)])

# %%
G_ex3 = nx.DiGraph()
G_ex3.add_nodes_from([1,2,3,4,5,6,7])
G_ex3.add_edges_from([(1,2), (2,1), (1,3), (3,1), (2,4), (4,2), (4,3), (3,4), (3,6), (6,3), (5,4), (4,5),(5,2),(2,5), (4,6), (6,4), (5,7), (7,5),(6,7),(7,6)])

# %%
# G_ud1 = nx.Graph()
# G_ud1.add_nodes_from([1,2,3,4,5])
# G_ud1.add_edges_from([(1,2),(2,1),(2,4),(4,2),(2,3),(3,2),(3,4),(4,3),(1,4),(4,1),(5,2),(5,1),(2,5),(1,5)])

# %%
# G_ud2 = nx.Graph()
# G_ud2.add_nodes_from([1,2,3,4,5])
# G_ud2.add_edges_from([(1,2), (2,1), (2,4), (4,2), (2,3), (3,2), (3,5), (5,3), (1,4), (4,1),(5,2),(2,5)])

# %%
G_ud3 = nx.Graph()
G_ud3.add_nodes_from([1,2,3,4,5,6,7])
G_ud3.add_edges_from([(1,2), (2,1), (1,3), (3,1), (2,4), (4,2), (4,3), (3,4), (3,6), (6,3), (5,4), (4,5),(5,2),(2,5), (4,6), (6,4), (5,7), (7,5),(6,7),(7,6)])

# %%
plt.rc("figure",figsize=(10,8))

pos = {1: (0.5, 9), 2:(-1, 6), 3: (2, 6), 4: (0.5, 3), 5: (-1,0), 6:(2,0), 7:(0.5,-3)}

options = {
    "with_labels": True,
    "font_size": 36,
    "node_size": 5000,
    "node_color": "magenta",
    "edge_color": "grey",
    "arrowsize": 20,
    'width': 2,
    "connectionstyle": 'arc3, rad = 0.05'
}

fig, ax = plt.subplots()
nx.draw_networkx(G_ex3, pos, **options)

ax.set_facecolor('white')
ax.axis('off')
fig.set_facecolor('white')
plt.show()
fig.savefig('G_ex2_diagram.png')

# %%
plt.rc("figure",figsize=(10,8))

pos = {1: (0.5, 9), 2:(-1, 6), 3: (2, 6), 4: (0.5, 3), 5: (-1,0), 6:(2,0), 7:(0.5,-3)}

options = {
    "with_labels": True,
    "font_size": 36,
    "node_size": 5000,
    "node_color": "magenta",
    "edge_color": "grey",
    "arrowsize": 20,
    'width': 2,
    "connectionstyle": 'arc3, rad = 0.05'
}

fig, ax = plt.subplots()
nx.draw_networkx(G_ud3, pos, **options)

ax.set_facecolor('white')
ax.axis('off')
fig.set_facecolor('white')
plt.show()
fig.savefig('G_ud3_diagram.png')

# %% [markdown]
# ## Create force-area plots

# %% [markdown]
# Prior to executing this function, the user should have extracted all relevant information from the graph. This includes the direction specific cycle weight and edge informtation.

# %% [markdown]
# Initialization:

# %%
node_list = get_nodes(G_ex3)
edge_list = get_edges(G_ex3)
weight_dict, weight_list = get_weights(G_ex3,max_val=10)
cycle_list = get_cycle_nodes(G_ud3)

num_cycles = len(cycle_list)
num_nodes = len(node_list)
num_edges = len(edge_list)

print(cycle_list)
print(weight_dict)
# Out:
# [[3, 4, 6], [2, 4, 5], [1, 2, 3, 4], [4, 5, 6, 7]]
# {(1, 2): 6, (1, 3): 2, (2, 1): 3, (2, 4): 3, (2, 5): 4, (3, 1): 7, (3, 4): 3, (3, 6): 9, (4, 2): 1, (4, 3): 5, (4, 5): 3, (4, 6): 9, (5, 4): 8, (5, 2): 8, (5, 7): 8, (6, 3): 3, (6, 4): 2, (6, 7): 6, (7, 5): 8, (7, 6): 6}

# %%
N = 2000
all_affinities = np.zeros((N,num_cycles))
all_areas = np.zeros((N,1))

observable_ex3 = [3, 5, 7, 9, 11, 13, 15]
tau_n = np.around(np.arange(0.01,2.0,step=.01), decimals = 2)

# %%
cycle_edges_forward, cycle_edges_backward, cycle_weights_forward, cycle_weights_backward = get_cycle_weights_edges(G_ud3,cycle_list,weight_dict)
print(cycle_weights_forward)
print(cycle_weights_backward)
# Out:
# [[3, 9, 3], [3, 3, 8], [6, None, 3, None], [3, None, 6, None]]
# [[5, 2, 9], [1, 8, 4], [3, None, 5, None], [8, None, 6, None]]

# %%
cycle_weights_forward, edge_tracker = initial_equilibrium_parameter_set(cycle_list,cycle_edges_forward,cycle_weights_forward,cycle_weights_backward)
print(edge_tracker)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c78b1f6412c9> in <module>
# ----> 1 cycle_weights_forward, edge_tracker = initial_equilibrium_parameter_set(cycle_list,cycle_edges_forward,cycle_weights_forward,cycle_weights_backward)
#       2 print(edge_tracker)
#
# ~/Desktop/Gunawardena-lab/my-stuff/noneq-signatures/general_graph_utils.py in initial_equilibrium_parameter_set(cycle_list, cycle_edges_forward, cycle_weights_forward, cycle_weights_backward)
#     204     for i in range(num_cycles):
#     205         if cycle_edges_forward[i][0] not in edge_tracker:
# --> 206             cycle_weights_forward[i][0] = (np.prod(cycle_weights_backward[i]))/(np.prod(cycle_weights_forward[i][1:]))
#     207             edge_tracker.append(cycle_edges_forward[i][0])
#     208
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    2997     10
#    2998     """
# -> 2999     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3000                           keepdims=keepdims, initial=initial, where=where)
#    3001
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

# %%
products_f, products_b = calculate_cycle_products(cycle_weights_forward,cycle_weights_backward)
total_affinities = calculate_affinities(products_f, products_b, cycle_list)
print(total_affinities)
# Out:
# [0. 0. 0. 0.]

# %%
all_affinities[0] = total_affinities
#print(all_affinities)

# %%
for i in range(num_cycles):
    weight_dict[edge_tracker[i]] = cycle_weights_forward[i][0]

print(weight_dict)
# Out:
# {(1, 2): 7, (1, 3): 8, (2, 1): 3, (2, 4): 6.0, (2, 5): 2.142857142857143, (3, 1): 8, (3, 4): 8, (3, 6): 6, (4, 2): 7, (4, 3): 4, (4, 5): 4.5, (4, 6): 0.3333333333333333, (5, 4): 1, (5, 2): 5, (5, 7): 9, (6, 3): 9, (6, 4): 1, (6, 7): 9, (7, 5): 6, (7, 6): 4}

# %%
weight_list = np.fromiter(weight_dict.values(), dtype=float)
print(weight_list)
# Out:
# [7.         8.         3.         6.         2.14285714 8.
#  8.         6.         7.         4.         4.5        0.33333333
#  1.         5.         9.         9.         1.         9.
#  6.         4.        ]

# %%
L = Laplacian_all(edge_list,weight_list,num_nodes,num_edges)
print(L)
# Out:
# [[-11.           7.           8.           0.           0.
#     0.           0.        ]
#  [  3.         -19.           0.           6.           2.14285714
#     0.           0.        ]
#  [  8.           0.         -21.           8.           0.
#     6.           0.        ]
#  [  0.           7.           4.         -16.           4.5
#     0.33333333   0.        ]
#  [  0.           5.           0.           1.         -12.64285714
#     0.           9.        ]
#  [  0.           0.           9.           1.           0.
#   -10.33333333   9.        ]
#  [  0.           0.           0.           0.           6.
#     4.         -18.        ]]

# %%
t, t_rev = NG_III_autocorrelation_analytical(observable_ex3,L,tau_n,alpha=1,beta=3)

# %%
all_areas[0] = np.abs(np.trapz(t)-np.trapz(t_rev))
#print(np.abs(np.trapz(t)-np.trapz(t_rev)))
#print(all_areas)

# %%
for i in tqdm(range(1,N)):

    # perturb parameter in each cycle
    for cycle in cycle_weights_forward:
        cycle[0] += 1
    
    # calculate and store the cycle affinity for each cycle
    products_f, products_b = calculate_cycle_products(cycle_weights_forward,cycle_weights_backward)
    total_affinities = calculate_affinities(products_f, products_b, cycle_list)
    
    all_affinities[i] = total_affinities
    
    # edit the record of the weights in the graph
    for j in range(num_cycles):
        weight_dict[edge_tracker[j]] = cycle_weights_forward[j][0]
    
    weight_list = np.fromiter(weight_dict.values(), dtype=float)
    
    # calculate the Laplacian
    L = Laplacian_all(edge_list,weight_list,num_nodes,num_edges)
    
    # calculate the autocorrelation functions
    t_ex1, t_rev_ex1 = NG_III_autocorrelation_analytical(observable_ex3,L,tau_n,alpha=1,beta=3)
    
    # calculate and store the area between them
    #print(np.abs(np.trapz(t_ex1)-np.trapz(t_rev_ex1)))
    all_areas[i] = np.abs(np.trapz(t_ex1)-np.trapz(t_rev_ex1))
# Out:
#  49%|████▉     | 975/1999 [01:19<01:23, 12.30it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-66bb9e66fe53> in <module>
#      21
#      22     # calculate the autocorrelation functions
# ---> 23     t_ex1, t_rev_ex1 = NG_III_autocorrelation_analytical(observable_ex3,L,tau_n,alpha=1,beta=3)
#      24
#      25     # calculate and store the area between them
#
# ~/Desktop/Gunawardena-lab/my-stuff/noneq-signatures/general_graph_utils.py in NG_III_autocorrelation_analytical(observable, L, tau_n, alpha, beta)
#     289     t_rev = np.zeros(len(tau_n))
#     290
# --> 291     list_result = list(map(lambda i: scipy.linalg.expm(L*i), tau_n))
#     292
#     293     # populate arrays with analytical solution to autocorrelation function
#
# ~/Desktop/Gunawardena-lab/my-stuff/noneq-signatures/general_graph_utils.py in <lambda>(i)
#     289     t_rev = np.zeros(len(tau_n))
#     290
# --> 291     list_result = list(map(lambda i: scipy.linalg.expm(L*i), tau_n))
#     292
#     293     # populate arrays with analytical solution to autocorrelation function
#
# ~/.local/lib/python3.8/site-packages/scipy/linalg/matfuncs.py in expm(A)
#     253     # Input checking and conversion is provided by sparse.linalg.expm().
#     254     import scipy.sparse.linalg
# --> 255     return scipy.sparse.linalg.expm(A)
#     256
#     257
#
# ~/.local/lib/python3.8/site-packages/scipy/sparse/linalg/matfuncs.py in expm(A)
#     590             [  0.        ,   0.        ,  20.08553692]])
#     591     """
# --> 592     return _expm(A, use_exact_onenorm='auto')
#     593
#     594
#
# ~/.local/lib/python3.8/site-packages/scipy/sparse/linalg/matfuncs.py in _expm(A, use_exact_onenorm)
#     669         s = 0
#     670     else:
# --> 671         s = max(int(np.ceil(np.log2(eta_5 / theta_13))), 0)
#     672     s = s + _ell(2**-s * h.A, 13)
#     673     U, V = h.pade13_scaled(s)
#
# KeyboardInterrupt:

# %%
#print(all_affinities)
# Out:
# [[ 0.00000000e+00  0.00000000e+00 -1.11022302e-16]
#  [ 1.39240308e-02  8.14216193e-03  1.77902637e-01]
#  [ 2.76568425e-02  1.62185641e-02  3.28884947e-01]
#  [ 4.12036159e-02  2.42302603e-02  4.60033457e-01]
#  [ 5.45693245e-02  3.21782790e-02  5.75959206e-01]
#  [ 6.77587445e-02  4.00636245e-02  6.79831405e-01]
#  [ 8.07764658e-02  4.78872775e-02  7.73922221e-01]
#  [ 9.36269014e-02  5.56501958e-02  8.59916324e-01]
#  [ 1.06314296e-01  6.33533152e-02  9.39097453e-01]
#  [ 1.18842736e-01  7.09975497e-02  1.01246634e+00]]

# %%
#print(all_areas)
# Out:
# [[3.6132089 ]
#  [3.02188464]
#  [2.44960826]
#  [1.89618913]
#  [1.36134846]
#  [0.84474005]
#  [0.34596702]
#  [0.13540472]
#  [0.59983562]
#  [1.04780372]]

# %% [markdown]
# ## So, the calculation is correct, but the allocation is not working. I have no idea why...

# %%
# plot formatting
plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(14,12))
# %config InlineBackend.figure_format = 'retina'
#plt.style.use('dark_background')
#plt.rcParams.update({"figure.facecolor": "111111",
#                   "savefig.facecolor": "111111"})

# %%
fig, ax = plt.subplots()
plt.plot(all_affinities[:,0],all_areas,linewidth=2,color='#ffa600')
plt.xlabel(r'Cycle affinity $\tilde{A}(C)$')
plt.ylabel(r'Area $\Delta A$ between $G^{\alpha,\beta}(\tau)$ and $G^{\beta,\alpha}(\tau)|$')
plt.title(r'Force-area curve: G_ex3, cycle 1')
fig.savefig('G_ex3cycle1_1.png')

# %%
fig, ax = plt.subplots()
plt.plot(all_affinities[:,1],all_areas,linewidth=2,color='#003f5c')
plt.xlabel(r'Cycle affinity $\tilde{A}(C)$')
plt.ylabel(r'Area $\Delta A$ between $G^{\alpha,\beta}(\tau)$ and $G^{\beta,\alpha}(\tau)|$')
plt.title(r'Force-area curve: G_ex2, cycle 2')
fig.savefig('G_ex2_cycle2_1.png')

# %%
# fig, ax = plt.subplots()
# plt.plot(all_affinities[:,2],all_areas,linewidth=2,color='#ff6361')
# plt.xlabel(r'Cycle affinity $\tilde{A}(C)$')
# plt.ylabel(r'Area $\Delta A$ between $G^{\alpha,\beta}(\tau)$ and $G^{\beta,\alpha}(\tau)|$')
# plt.title(r'Force-area curve: G_ex1, cycle 3')
# fig.savefig('G_ex1_cycle3_2.png')

# %%
fig, ax = plt.subplots()
plt.plot(all_affinities[:,0],all_areas,label='cycle 1',linewidth=2,color='#ffa600')
plt.plot(all_affinities[:,1],all_areas,label='cycle 2',linewidth=2,color='#003f5c')
#plt.plot(all_affinities[:,2],all_areas,label='cycle 3',linewidth=2,color='#ff6361')
plt.legend()
plt.xlabel(r'Cycle affinity $\tilde{A}(C)$')
plt.ylabel(r'Area $\Delta A$ between $G^{\alpha,\beta}(\tau)$ and $G^{\beta,\alpha}(\tau)|$')
plt.title(r'Force-area curve: G_ex2, all cycles')
fig.savefig('G_ex2_allcycles_1.png')

# %% [markdown]
# ## Troubleshooting force-area plots
#
# Need to double check the area calculation. Something isn't going right here.

# %%
weight_dict = {(1, 2): 9, (1, 4): 4, (1, 5): 2, (2, 1): 2, (2, 4): 0.6666666666666666, (2, 3): 0.6666666666666666, (2, 5): 0.16666666666666666, (3, 2): 4, (3, 4): 8, (4, 2): 6, (4, 3): 2, (4, 1): 8, (5, 2): 3, (5, 1): 8}

# %%
weight_list = np.fromiter(weight_dict.values(), dtype=float)
print(weight_list)
# Out:
# [9.         4.         2.         2.         0.66666667 0.66666667
#  0.16666667 4.         8.         6.         2.         8.
#  3.         8.        ]

# %%
L = Laplacian_all(edge_list,weight_list,num_nodes,num_edges)
t, t_rev = NG_III_autocorrelation_analytical(observable_ex1,L,tau_n,alpha=1,beta=3)

# %%
np.abs(np.trapz(t)-np.trapz(t_rev))
# Out:
# 173.78893584990874
